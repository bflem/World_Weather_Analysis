# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 740

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=1ba809f84a2edb2f0ac3f3f43124f13b

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | castro
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | payson
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | saint-joseph
# Processing Record 7 of Set 1 | geraldton
# Processing Record 8 of Set 1 | visby
# Processing Record 9 of Set 1 | puerto ayora
# Processing Record 10 of Set 1 | mar del plata
# Processing Record 11 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 1 | padang
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | ambulu
# Processing Record 15 of Set 1 | ios
# Processing Record 16 of Set 1 | asau
# Processing Record 17 of Set 1 | saskylakh
# Processing Record 18 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 1 | carnarvon
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | pangai
# Processing Record 23 of Set 1 | barrow
# Processing Record 24 of Set 1 | livingston
# Processing Record 25 of Set 1 | sao sebastiao
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | katsuura
# Processing Record 28 of Set 1 | yeniseysk
# Processing Record 29 of Set 1 | punta arenas
# Processing Record 30 of Set 1 | mirandola
# Processing Record 31 of Set 1 | osecina
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | torbay
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | egvekinot
# Processing Record 36 of Set 1 | harbour breton
# Processing Record 37 of Set 1 | cape town
# Processing Record 38 of Set 1 | thompson
# Processing Record 39 of Set 1 | hermosillo
# Processing Record 40 of Set 1 | jamestown
# Processing Record 41 of Set 1 | kapaa
# Processing Record 42 of Set 1 | hermanus
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | cairo
# Processing Record 45 of Set 1 | aklavik
# Processing Record 46 of Set 1 | yellowknife
# Processing Record 47 of Set 1 | avarua
# Processing Record 48 of Set 1 | safaga
# Processing Record 49 of Set 1 | kirakira
# Processing Record 50 of Set 1 | burica
# City not found. Skipping...
# Processing Record 1 of Set 2 | cidreira
# Processing Record 2 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 3 of Set 2 | ankpa
# Processing Record 4 of Set 2 | mubi
# Processing Record 5 of Set 2 | caravelas
# Processing Record 6 of Set 2 | ludvika
# Processing Record 7 of Set 2 | westport
# Processing Record 8 of Set 2 | acapulco
# Processing Record 9 of Set 2 | hobart
# Processing Record 10 of Set 2 | okhotsk
# Processing Record 11 of Set 2 | victoria
# Processing Record 12 of Set 2 | aljezur
# Processing Record 13 of Set 2 | sao joao do paraiso
# Processing Record 14 of Set 2 | guanay
# Processing Record 15 of Set 2 | souillac
# Processing Record 16 of Set 2 | port elizabeth
# Processing Record 17 of Set 2 | tonstad
# Processing Record 18 of Set 2 | meadow lake
# Processing Record 19 of Set 2 | margate
# Processing Record 20 of Set 2 | harare
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | sisimiut
# Processing Record 23 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 2 | mont-dore
# Processing Record 25 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 26 of Set 2 | mayo
# Processing Record 27 of Set 2 | graaff-reinet
# Processing Record 28 of Set 2 | sola
# Processing Record 29 of Set 2 | buraydah
# Processing Record 30 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | qeshm
# Processing Record 33 of Set 2 | uberlandia
# Processing Record 34 of Set 2 | georgetown
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | ostrovnoy
# Processing Record 37 of Set 2 | sao joao da barra
# Processing Record 38 of Set 2 | rudbar
# Processing Record 39 of Set 2 | dingle
# Processing Record 40 of Set 2 | mahbubnagar
# Processing Record 41 of Set 2 | bilibino
# Processing Record 42 of Set 2 | upernavik
# Processing Record 43 of Set 2 | sinnamary
# Processing Record 44 of Set 2 | te anau
# Processing Record 45 of Set 2 | khatanga
# Processing Record 46 of Set 2 | bluff
# Processing Record 47 of Set 2 | vardo
# Processing Record 48 of Set 2 | saint anthony
# Processing Record 49 of Set 2 | gambela
# Processing Record 50 of Set 2 | gavle
# Processing Record 1 of Set 3 | boden
# Processing Record 2 of Set 3 | anadyr
# Processing Record 3 of Set 3 | zenzeli
# Processing Record 4 of Set 3 | east london
# Processing Record 5 of Set 3 | saint-pierre
# Processing Record 6 of Set 3 | olinda
# Processing Record 7 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 3 | san anselmo
# Processing Record 9 of Set 3 | arraial do cabo
# Processing Record 10 of Set 3 | dukat
# Processing Record 11 of Set 3 | butaritari
# Processing Record 12 of Set 3 | veraval
# Processing Record 13 of Set 3 | la ronge
# Processing Record 14 of Set 3 | upata
# Processing Record 15 of Set 3 | tommot
# Processing Record 16 of Set 3 | husavik
# Processing Record 17 of Set 3 | saint george
# Processing Record 18 of Set 3 | mitsamiouli
# Processing Record 19 of Set 3 | ribeira grande
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | dikson
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | ketchikan
# Processing Record 24 of Set 3 | umm kaddadah
# Processing Record 25 of Set 3 | kaitangata
# Processing Record 26 of Set 3 | derzhavinsk
# Processing Record 27 of Set 3 | seymchan
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | camana
# Processing Record 30 of Set 3 | isangel
# Processing Record 31 of Set 3 | mahebourg
# Processing Record 32 of Set 3 | longyearbyen
# Processing Record 33 of Set 3 | nuuk
# Processing Record 34 of Set 3 | port augusta
# Processing Record 35 of Set 3 | cabo san lucas
# Processing Record 36 of Set 3 | bonthe
# Processing Record 37 of Set 3 | uncia
# Processing Record 38 of Set 3 | vila do maio
# Processing Record 39 of Set 3 | bathsheba
# Processing Record 40 of Set 3 | adrar
# Processing Record 41 of Set 3 | tuatapere
# Processing Record 42 of Set 3 | nikolskoye
# Processing Record 43 of Set 3 | lagoa
# Processing Record 44 of Set 3 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 3 | bengkulu
# Processing Record 46 of Set 3 | vaini
# Processing Record 47 of Set 3 | luderitz
# Processing Record 48 of Set 3 | tubruq
# City not found. Skipping...
# Processing Record 49 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | klaksvik
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | urcos
# Processing Record 3 of Set 4 | abu zabad
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | mackay
# Processing Record 6 of Set 4 | belmonte
# Processing Record 7 of Set 4 | mount gambier
# Processing Record 8 of Set 4 | santa cruz
# Processing Record 9 of Set 4 | tainan
# Processing Record 10 of Set 4 | lesosibirsk
# Processing Record 11 of Set 4 | luanda
# Processing Record 12 of Set 4 | namibe
# Processing Record 13 of Set 4 | dunedin
# Processing Record 14 of Set 4 | port alfred
# Processing Record 15 of Set 4 | labuhan
# Processing Record 16 of Set 4 | boromo
# Processing Record 17 of Set 4 | provideniya
# Processing Record 18 of Set 4 | gizo
# Processing Record 19 of Set 4 | ales
# Processing Record 20 of Set 4 | bibiani
# Processing Record 21 of Set 4 | alofi
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | hamilton
# Processing Record 24 of Set 4 | chokurdakh
# Processing Record 25 of Set 4 | moissala
# Processing Record 26 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 27 of Set 4 | chicama
# Processing Record 28 of Set 4 | clyde river
# Processing Record 29 of Set 4 | mariental
# Processing Record 30 of Set 4 | pimentel
# Processing Record 31 of Set 4 | edd
# Processing Record 32 of Set 4 | ponta do sol
# Processing Record 33 of Set 4 | xiamen
# Processing Record 34 of Set 4 | vuktyl
# Processing Record 35 of Set 4 | redmond
# Processing Record 36 of Set 4 | tasiilaq
# Processing Record 37 of Set 4 | krasnoselkup
# Processing Record 38 of Set 4 | marsabit
# Processing Record 39 of Set 4 | narsaq
# Processing Record 40 of Set 4 | leningradskiy
# Processing Record 41 of Set 4 | sayyan
# Processing Record 42 of Set 4 | trairi
# Processing Record 43 of Set 4 | vitim
# Processing Record 44 of Set 4 | los llanos de aridane
# Processing Record 45 of Set 4 | dickinson
# Processing Record 46 of Set 4 | guerrero negro
# Processing Record 47 of Set 4 | lipari
# Processing Record 48 of Set 4 | mountain home
# Processing Record 49 of Set 4 | belaya gora
# Processing Record 50 of Set 4 | port macquarie
# Processing Record 1 of Set 5 | tiksi
# Processing Record 2 of Set 5 | naivasha
# Processing Record 3 of Set 5 | san quintin
# Processing Record 4 of Set 5 | kaya
# Processing Record 5 of Set 5 | hanstholm
# Processing Record 6 of Set 5 | poum
# Processing Record 7 of Set 5 | kangaatsiaq
# Processing Record 8 of Set 5 | hobyo
# Processing Record 9 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 5 | broome
# Processing Record 11 of Set 5 | beloha
# Processing Record 12 of Set 5 | tocopilla
# Processing Record 13 of Set 5 | ahvaz
# Processing Record 14 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 15 of Set 5 | pevek
# Processing Record 16 of Set 5 | ambodifototra
# City not found. Skipping...
# Processing Record 17 of Set 5 | jiazi
# Processing Record 18 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 5 | chepareria
# Processing Record 20 of Set 5 | new norfolk
# Processing Record 21 of Set 5 | grand-lahou
# Processing Record 22 of Set 5 | batagay-alyta
# Processing Record 23 of Set 5 | shwebo
# Processing Record 24 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 25 of Set 5 | kasempa
# Processing Record 26 of Set 5 | bolobo
# Processing Record 27 of Set 5 | yuanping
# Processing Record 28 of Set 5 | cherskiy
# Processing Record 29 of Set 5 | gogrial
# Processing Record 30 of Set 5 | moron
# Processing Record 31 of Set 5 | ayagoz
# Processing Record 32 of Set 5 | horasan
# Processing Record 33 of Set 5 | rio claro
# Processing Record 34 of Set 5 | merauke
# Processing Record 35 of Set 5 | kahului
# Processing Record 36 of Set 5 | shache
# Processing Record 37 of Set 5 | atbasar
# Processing Record 38 of Set 5 | tual
# Processing Record 39 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 5 | dvinskoy
# Processing Record 41 of Set 5 | nacogdoches
# Processing Record 42 of Set 5 | naron
# Processing Record 43 of Set 5 | puerto narino
# Processing Record 44 of Set 5 | laguna
# Processing Record 45 of Set 5 | nouadhibou
# Processing Record 46 of Set 5 | jalu
# Processing Record 47 of Set 5 | deputatskiy
# Processing Record 48 of Set 5 | berlevag
# Processing Record 49 of Set 5 | bandarbeyla
# Processing Record 50 of Set 5 | zahirabad
# Processing Record 1 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 2 of Set 6 | saldanha
# Processing Record 3 of Set 6 | ridgecrest
# Processing Record 4 of Set 6 | kurilsk
# Processing Record 5 of Set 6 | tilichiki
# Processing Record 6 of Set 6 | xichang
# Processing Record 7 of Set 6 | kavaratti
# Processing Record 8 of Set 6 | cuiluan
# Processing Record 9 of Set 6 | namatanai
# Processing Record 10 of Set 6 | appleton
# Processing Record 11 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 12 of Set 6 | ixtapa
# Processing Record 13 of Set 6 | bereznehuvate
# Processing Record 14 of Set 6 | prainha
# Processing Record 15 of Set 6 | lata
# Processing Record 16 of Set 6 | tarko-sale
# Processing Record 17 of Set 6 | mardin
# Processing Record 18 of Set 6 | lorengau
# Processing Record 19 of Set 6 | cockburn town
# Processing Record 20 of Set 6 | srandakan
# Processing Record 21 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 22 of Set 6 | ojinaga
# Processing Record 23 of Set 6 | uruzgan
# Processing Record 24 of Set 6 | tazovskiy
# Processing Record 25 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 6 | anan
# Processing Record 27 of Set 6 | akyab
# Processing Record 28 of Set 6 | prado
# Processing Record 29 of Set 6 | macas
# Processing Record 30 of Set 6 | saint-francois
# Processing Record 31 of Set 6 | kruisfontein
# Processing Record 32 of Set 6 | saint-augustin
# Processing Record 33 of Set 6 | beringovskiy
# Processing Record 34 of Set 6 | kendari
# Processing Record 35 of Set 6 | tula
# Processing Record 36 of Set 6 | rameshki
# Processing Record 37 of Set 6 | vestmannaeyjar
# Processing Record 38 of Set 6 | santa maria da vitoria
# Processing Record 39 of Set 6 | tromso
# Processing Record 40 of Set 6 | korla
# Processing Record 41 of Set 6 | winsford
# Processing Record 42 of Set 6 | broken hill
# Processing Record 43 of Set 6 | brunico
# Processing Record 44 of Set 6 | bobo dioulasso
# Processing Record 45 of Set 6 | west richland
# Processing Record 46 of Set 6 | wuxue
# Processing Record 47 of Set 6 | lebu
# Processing Record 48 of Set 6 | sur
# Processing Record 49 of Set 6 | alice springs
# Processing Record 50 of Set 6 | mamou
# Processing Record 1 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 7 | puerto del rosario
# Processing Record 3 of Set 7 | hasaki
# Processing Record 4 of Set 7 | palu
# Processing Record 5 of Set 7 | palmer
# Processing Record 6 of Set 7 | hithadhoo
# Processing Record 7 of Set 7 | aswan
# Processing Record 8 of Set 7 | north bend
# Processing Record 9 of Set 7 | taoudenni
# Processing Record 10 of Set 7 | lavrentiya
# Processing Record 11 of Set 7 | walla walla
# Processing Record 12 of Set 7 | iquitos
# Processing Record 13 of Set 7 | san francisco
# Processing Record 14 of Set 7 | timra
# Processing Record 15 of Set 7 | memari
# Processing Record 16 of Set 7 | vila franca do campo
# Processing Record 17 of Set 7 | touros
# Processing Record 18 of Set 7 | codrington
# Processing Record 19 of Set 7 | san patricio
# Processing Record 20 of Set 7 | douai
# Processing Record 21 of Set 7 | sebinkarahisar
# Processing Record 22 of Set 7 | severo-kurilsk
# Processing Record 23 of Set 7 | dunmore east
# Processing Record 24 of Set 7 | mocuba
# Processing Record 25 of Set 7 | kloulklubed
# Processing Record 26 of Set 7 | naze
# Processing Record 27 of Set 7 | sumbawa
# City not found. Skipping...
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | lasa
# Processing Record 30 of Set 7 | sosnovka
# Processing Record 31 of Set 7 | rocha
# Processing Record 32 of Set 7 | port blair
# Processing Record 33 of Set 7 | havre-saint-pierre
# Processing Record 34 of Set 7 | concordia
# Processing Record 35 of Set 7 | saint-philippe
# Processing Record 36 of Set 7 | aljustrel
# Processing Record 37 of Set 7 | constitucion
# Processing Record 38 of Set 7 | mucurapo
# Processing Record 39 of Set 7 | mana
# Processing Record 40 of Set 7 | evensk
# Processing Record 41 of Set 7 | ravenna
# Processing Record 42 of Set 7 | katherine
# Processing Record 43 of Set 7 | yakima
# Processing Record 44 of Set 7 | alta floresta
# Processing Record 45 of Set 7 | impfondo
# Processing Record 46 of Set 7 | djambala
# Processing Record 47 of Set 7 | pachino
# Processing Record 48 of Set 7 | ancud
# Processing Record 49 of Set 7 | ilulissat
# Processing Record 50 of Set 7 | udimskiy
# Processing Record 1 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 8 | magan
# Processing Record 3 of Set 8 | flin flon
# Processing Record 4 of Set 8 | jever
# Processing Record 5 of Set 8 | boguchany
# Processing Record 6 of Set 8 | nome
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | kodinsk
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | atikokan
# Processing Record 11 of Set 8 | camopi
# Processing Record 12 of Set 8 | srednekolymsk
# Processing Record 13 of Set 8 | vallenar
# Processing Record 14 of Set 8 | port-gentil
# Processing Record 15 of Set 8 | novominskaya
# Processing Record 16 of Set 8 | koutsouras
# Processing Record 17 of Set 8 | moose factory
# Processing Record 18 of Set 8 | temaraia
# City not found. Skipping...
# Processing Record 19 of Set 8 | dossor
# Processing Record 20 of Set 8 | karatau
# Processing Record 21 of Set 8 | mitzic
# Processing Record 22 of Set 8 | natal
# Processing Record 23 of Set 8 | colares
# Processing Record 24 of Set 8 | melilla
# Processing Record 25 of Set 8 | malinovoye ozero
# Processing Record 26 of Set 8 | banamba
# Processing Record 27 of Set 8 | preobrazheniye
# Processing Record 28 of Set 8 | east stroudsburg
# Processing Record 29 of Set 8 | novaya igirma
# Processing Record 30 of Set 8 | kismayo
# Processing Record 31 of Set 8 | cairns
# Processing Record 32 of Set 8 | wenatchee
# Processing Record 33 of Set 8 | scottsburgh
# City not found. Skipping...
# Processing Record 34 of Set 8 | varkkallai
# Processing Record 35 of Set 8 | maraba
# Processing Record 36 of Set 8 | bethel
# Processing Record 37 of Set 8 | loten
# Processing Record 38 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 39 of Set 8 | fort payne
# Processing Record 40 of Set 8 | boa vista
# Processing Record 41 of Set 8 | ponta delgada
# Processing Record 42 of Set 8 | kidal
# Processing Record 43 of Set 8 | atambua
# Processing Record 44 of Set 8 | leningradskaya
# Processing Record 45 of Set 8 | bambous virieux
# Processing Record 46 of Set 8 | nyanza
# Processing Record 47 of Set 8 | aitape
# Processing Record 48 of Set 8 | puerto colombia
# Processing Record 49 of Set 8 | amapa
# Processing Record 50 of Set 8 | ust-kuyga
# Processing Record 1 of Set 9 | ahipara
# Processing Record 2 of Set 9 | finschhafen
# Processing Record 3 of Set 9 | bafoulabe
# Processing Record 4 of Set 9 | banjar
# Processing Record 5 of Set 9 | college
# Processing Record 6 of Set 9 | qaanaaq
# Processing Record 7 of Set 9 | ashtian
# Processing Record 8 of Set 9 | falam
# Processing Record 9 of Set 9 | pringsewu
# Processing Record 10 of Set 9 | zheleznodorozhnyy
# Processing Record 11 of Set 9 | zyryanka
# Processing Record 12 of Set 9 | mumford
# Processing Record 13 of Set 9 | qui nhon
# Processing Record 14 of Set 9 | mount isa
# Processing Record 15 of Set 9 | uusikaupunki
# Processing Record 16 of Set 9 | mecca
# Processing Record 17 of Set 9 | kiunga
# Processing Record 18 of Set 9 | megion
# Processing Record 19 of Set 9 | usinsk
# Processing Record 20 of Set 9 | gazli
# Processing Record 21 of Set 9 | caceres
# Processing Record 22 of Set 9 | dzilam gonzalez
# Processing Record 23 of Set 9 | muyezerskiy
# Processing Record 24 of Set 9 | norman wells
# Processing Record 25 of Set 9 | flinders
# Processing Record 26 of Set 9 | oregon city
# Processing Record 27 of Set 9 | zuwarah
# Processing Record 28 of Set 9 | eureka
# Processing Record 29 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 30 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 9 | haines junction
# Processing Record 32 of Set 9 | vao
# Processing Record 33 of Set 9 | cozumel
# Processing Record 34 of Set 9 | macia
# Processing Record 35 of Set 9 | salalah
# Processing Record 36 of Set 9 | portree
# Processing Record 37 of Set 9 | rosto do cao
# City not found. Skipping...
# Processing Record 38 of Set 9 | mareeba
# Processing Record 39 of Set 9 | siwana
# Processing Record 40 of Set 9 | mulanje
# Processing Record 41 of Set 9 | svirstroy
# Processing Record 42 of Set 9 | poronaysk
# Processing Record 43 of Set 9 | hovd
# Processing Record 44 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 46 of Set 9 | ikryanoye
# Processing Record 47 of Set 9 | coos bay
# Processing Record 48 of Set 9 | rosetta
# Processing Record 49 of Set 9 | ugoofaaru
# Processing Record 50 of Set 9 | benghazi
# Processing Record 1 of Set 10 | boca do acre
# Processing Record 2 of Set 10 | lazaro cardenas
# Processing Record 3 of Set 10 | russell
# Processing Record 4 of Set 10 | dejen
# Processing Record 5 of Set 10 | mazagao
# Processing Record 6 of Set 10 | aasiaat
# Processing Record 7 of Set 10 | chaoyang
# Processing Record 8 of Set 10 | upington
# Processing Record 9 of Set 10 | paciran
# Processing Record 10 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 10 | port lincoln
# Processing Record 12 of Set 10 | sao filipe
# Processing Record 13 of Set 10 | portland
# Processing Record 14 of Set 10 | khani
# Processing Record 15 of Set 10 | tymovskoye
# Processing Record 16 of Set 10 | grindavik
# Processing Record 17 of Set 10 | smoky lake
# Processing Record 18 of Set 10 | sanary-sur-mer
# Processing Record 19 of Set 10 | vanimo
# Processing Record 20 of Set 10 | salina cruz
# Processing Record 21 of Set 10 | yar-sale
# Processing Record 22 of Set 10 | sungaipenuh
# Processing Record 23 of Set 10 | puerto escondido
# Processing Record 24 of Set 10 | joensuu
# Processing Record 25 of Set 10 | la rioja
# Processing Record 26 of Set 10 | pushkino
# Processing Record 27 of Set 10 | sovetskiy
# Processing Record 28 of Set 10 | manuk mangkaw
# Processing Record 29 of Set 10 | nemuro
# Processing Record 30 of Set 10 | batemans bay
# Processing Record 31 of Set 10 | villazon
# Processing Record 32 of Set 10 | norsup
# Processing Record 33 of Set 10 | kyaikkami
# Processing Record 34 of Set 10 | bunia
# Processing Record 35 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 10 | muros
# Processing Record 37 of Set 10 | sistranda
# Processing Record 38 of Set 10 | bilma
# Processing Record 39 of Set 10 | kropotkin
# Processing Record 40 of Set 10 | gannan
# Processing Record 41 of Set 10 | dunmore town
# Processing Record 42 of Set 10 | xinyu
# Processing Record 43 of Set 10 | roswell
# Processing Record 44 of Set 10 | zhigansk
# Processing Record 45 of Set 10 | bahir dar
# Processing Record 46 of Set 10 | huadian
# Processing Record 47 of Set 10 | vila
# Processing Record 48 of Set 10 | lakatoro
# Processing Record 49 of Set 10 | kon tum
# Processing Record 50 of Set 10 | sabha
# Processing Record 1 of Set 11 | birao
# Processing Record 2 of Set 11 | kavieng
# Processing Record 3 of Set 11 | coracao de maria
# Processing Record 4 of Set 11 | itarema
# Processing Record 5 of Set 11 | geresk
# City not found. Skipping...
# Processing Record 6 of Set 11 | ndende
# Processing Record 7 of Set 11 | teberda
# Processing Record 8 of Set 11 | mehamn
# Processing Record 9 of Set 11 | itaituba
# Processing Record 10 of Set 11 | muli
# Processing Record 11 of Set 11 | qaqortoq
# Processing Record 12 of Set 11 | uvira
# Processing Record 13 of Set 11 | simbahan
# Processing Record 14 of Set 11 | zhangjiakou
# Processing Record 15 of Set 11 | mercedes
# Processing Record 16 of Set 11 | pedernales
# Processing Record 17 of Set 11 | mazamet
# Processing Record 18 of Set 11 | borba
# Processing Record 19 of Set 11 | morgan city
# Processing Record 20 of Set 11 | havoysund
# Processing Record 21 of Set 11 | salamiyah
# Processing Record 22 of Set 11 | hofn
# Processing Record 23 of Set 11 | banyo
# Processing Record 24 of Set 11 | manzanillo
# Processing Record 25 of Set 11 | kununurra
# Processing Record 26 of Set 11 | soyo
# Processing Record 27 of Set 11 | meulaboh
# Processing Record 28 of Set 11 | wick
# Processing Record 29 of Set 11 | komsomolskiy
# Processing Record 30 of Set 11 | rusape
# Processing Record 31 of Set 11 | wangqing
# Processing Record 32 of Set 11 | kawalu
# Processing Record 33 of Set 11 | fuling
# Processing Record 34 of Set 11 | murmashi
# Processing Record 35 of Set 11 | nanakuli
# Processing Record 36 of Set 11 | boshkengash
# Processing Record 37 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 11 | morondava
# Processing Record 39 of Set 11 | puerto asis
# Processing Record 40 of Set 11 | cayenne
# Processing Record 41 of Set 11 | bodden town
# Processing Record 42 of Set 11 | kamaishi
# Processing Record 43 of Set 11 | iqaluit
# Processing Record 44 of Set 11 | pangnirtung
# Processing Record 45 of Set 11 | necochea
# Processing Record 46 of Set 11 | rio grande
# Processing Record 47 of Set 11 | hay river
# Processing Record 48 of Set 11 | vieste
# Processing Record 49 of Set 11 | scarborough
# Processing Record 50 of Set 11 | riberalta
# Processing Record 1 of Set 12 | loukhi
# Processing Record 2 of Set 12 | ponta pora
# Processing Record 3 of Set 12 | hihifo
# City not found. Skipping...
# Processing Record 4 of Set 12 | khanpur
# Processing Record 5 of Set 12 | metro
# Processing Record 6 of Set 12 | cumberland
# Processing Record 7 of Set 12 | severobaykalsk
# Processing Record 8 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 9 of Set 12 | zhezkazgan
# Processing Record 10 of Set 12 | dong hoi
# Processing Record 11 of Set 12 | jiddah
# City not found. Skipping...
# Processing Record 12 of Set 12 | elko
# Processing Record 13 of Set 12 | honningsvag
# Processing Record 14 of Set 12 | tomelloso
# Processing Record 15 of Set 12 | spokane
# Processing Record 16 of Set 12 | rancho palos verdes
# Processing Record 17 of Set 12 | rio gallegos
# Processing Record 18 of Set 12 | coahuayana
# Processing Record 19 of Set 12 | benevento
# Processing Record 20 of Set 12 | lipin bor
# Processing Record 21 of Set 12 | san jose
# Processing Record 22 of Set 12 | buala
# Processing Record 23 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 24 of Set 12 | beira
# Processing Record 25 of Set 12 | kathu
# Processing Record 26 of Set 12 | goure
# Processing Record 27 of Set 12 | lieksa
# Processing Record 28 of Set 12 | bonfim
# Processing Record 29 of Set 12 | angoche
# Processing Record 30 of Set 12 | swan hill
# Processing Record 31 of Set 12 | dudinka
# Processing Record 32 of Set 12 | ukiah
# Processing Record 33 of Set 12 | gat
# Processing Record 34 of Set 12 | bontang
# Processing Record 35 of Set 12 | swan river
# Processing Record 36 of Set 12 | prince rupert
# Processing Record 37 of Set 12 | manado
# Processing Record 38 of Set 12 | mao
# Processing Record 39 of Set 12 | baena
# Processing Record 40 of Set 12 | inzhavino
# Processing Record 41 of Set 12 | hualmay
# Processing Record 42 of Set 12 | rock sound
# Processing Record 43 of Set 12 | oleggio
# Processing Record 44 of Set 12 | albesti
# Processing Record 45 of Set 12 | duluth
# Processing Record 46 of Set 12 | trelew
# Processing Record 47 of Set 12 | oranjemund
# Processing Record 48 of Set 12 | kibala
# Processing Record 49 of Set 12 | buin
# Processing Record 50 of Set 12 | belyy yar
# Processing Record 1 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 2 of Set 13 | tenkodogo
# Processing Record 3 of Set 13 | hami
# Processing Record 4 of Set 13 | penzance
# Processing Record 5 of Set 13 | sumbe
# Processing Record 6 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 13 | byron bay
# Processing Record 8 of Set 13 | najran
# Processing Record 9 of Set 13 | sobolevo
# Processing Record 10 of Set 13 | tela
# Processing Record 11 of Set 13 | houma
# Processing Record 12 of Set 13 | verkhnevilyuysk
# Processing Record 13 of Set 13 | ambon
# Processing Record 14 of Set 13 | zhireken
# Processing Record 15 of Set 13 | carutapera
# Processing Record 16 of Set 13 | bubaque
# Processing Record 17 of Set 13 | antsohihy
# Processing Record 18 of Set 13 | tidore
# City not found. Skipping...
# Processing Record 19 of Set 13 | storforshei
# Processing Record 20 of Set 13 | kamenka
# Processing Record 21 of Set 13 | buluang
# Processing Record 22 of Set 13 | northam
# Processing Record 23 of Set 13 | turukhansk
# Processing Record 24 of Set 13 | sorland
# Processing Record 25 of Set 13 | bo
# City not found. Skipping...
# Processing Record 26 of Set 13 | shinpokh
# Processing Record 27 of Set 13 | la palma
# Processing Record 28 of Set 13 | abay
# Processing Record 29 of Set 13 | zhanaozen
# Processing Record 30 of Set 13 | borazjan
# Processing Record 31 of Set 13 | kargat
# Processing Record 32 of Set 13 | chiman
# Processing Record 33 of Set 13 | grand-santi
# Processing Record 34 of Set 13 | seoul
# Processing Record 35 of Set 13 | kelso
# Processing Record 36 of Set 13 | kupang
# Processing Record 37 of Set 13 | antofagasta
# Processing Record 38 of Set 13 | brae
# Processing Record 39 of Set 13 | manokwari
# Processing Record 40 of Set 13 | wahiawa
# Processing Record 41 of Set 13 | kenai
# Processing Record 42 of Set 13 | were ilu
# Processing Record 43 of Set 13 | matagami
# Processing Record 44 of Set 13 | kijang
# Processing Record 45 of Set 13 | chateaubelair
# Processing Record 46 of Set 13 | kalispell
# Processing Record 47 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 13 | aksu
# Processing Record 49 of Set 13 | ufa
# Processing Record 50 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 1 of Set 14 | nankana sahib
# Processing Record 2 of Set 14 | tahta
# Processing Record 3 of Set 14 | solnechnyy
# Processing Record 4 of Set 14 | doba
# Processing Record 5 of Set 14 | gwadar
# Processing Record 6 of Set 14 | tautira
# Processing Record 7 of Set 14 | chotila
# Processing Record 8 of Set 14 | faya
# Processing Record 9 of Set 14 | lyngseidet
# Processing Record 10 of Set 14 | calvinia
# Processing Record 11 of Set 14 | rura
# Processing Record 12 of Set 14 | dubti
# Processing Record 13 of Set 14 | ritchie
# Processing Record 14 of Set 14 | trois-pistoles
# City not found. Skipping...
# Processing Record 15 of Set 14 | marawi
# Processing Record 16 of Set 14 | gorahun
# Processing Record 17 of Set 14 | atchison
# Processing Record 18 of Set 14 | tir pol
# City not found. Skipping...
# Processing Record 19 of Set 14 | puerto cabezas
# Processing Record 20 of Set 14 | tandil
# Processing Record 21 of Set 14 | birjand
# Processing Record 22 of Set 14 | abu dhabi
# Processing Record 23 of Set 14 | itanhem
# Processing Record 24 of Set 14 | goderich
# Processing Record 25 of Set 14 | narva-joesuu
# Processing Record 26 of Set 14 | delta del tigre
# Processing Record 27 of Set 14 | maceio
# Processing Record 28 of Set 14 | ningan
# City not found. Skipping...
# Processing Record 29 of Set 14 | lively
# Processing Record 30 of Set 14 | rorvik
# Processing Record 31 of Set 14 | pacific grove
# Processing Record 32 of Set 14 | gamba
# Processing Record 33 of Set 14 | salinopolis
# Processing Record 34 of Set 14 | fort nelson
# Processing Record 35 of Set 14 | weihe
# Processing Record 36 of Set 14 | oxford
# Processing Record 37 of Set 14 | langenau
# Processing Record 38 of Set 14 | kungurtug
# Processing Record 39 of Set 14 | valerianovsk
# Processing Record 40 of Set 14 | yandoon
# City not found. Skipping...
# Processing Record 41 of Set 14 | dongsheng
# Processing Record 42 of Set 14 | banff
# Processing Record 43 of Set 14 | artyk
# City not found. Skipping...
# Processing Record 44 of Set 14 | itoman
# Processing Record 45 of Set 14 | bridlington
# Processing Record 46 of Set 14 | parkes
# Processing Record 47 of Set 14 | pochutla
# Processing Record 48 of Set 14 | lindi
# Processing Record 49 of Set 14 | lysyanka
# Processing Record 50 of Set 14 | biltine
# Processing Record 1 of Set 15 | kosh-agach
# Processing Record 2 of Set 15 | balkhash
# Processing Record 3 of Set 15 | falesti
# Processing Record 4 of Set 15 | mmabatho
# Processing Record 5 of Set 15 | ukrayinka
# Processing Record 6 of Set 15 | olafsvik
# Processing Record 7 of Set 15 | talaya
# Processing Record 8 of Set 15 | launceston
# Processing Record 9 of Set 15 | vostok
# Processing Record 10 of Set 15 | makubetsu
# Processing Record 11 of Set 15 | englewood
# Processing Record 12 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 15 | chishtian mandi
# Processing Record 14 of Set 15 | funtua
# Processing Record 15 of Set 15 | noumea
# Processing Record 16 of Set 15 | ipoti
# Processing Record 17 of Set 15 | bowen
# Processing Record 18 of Set 15 | marsh harbour
# Processing Record 19 of Set 15 | tezu
# Processing Record 20 of Set 15 | lubbock
# Processing Record 21 of Set 15 | melfort
# Processing Record 22 of Set 15 | valkeala
# Processing Record 23 of Set 15 | aranos
# Processing Record 24 of Set 15 | lingyuan
# Processing Record 25 of Set 15 | nicoya
# Processing Record 26 of Set 15 | yulara
# Processing Record 27 of Set 15 | ballina
# Processing Record 28 of Set 15 | henties bay
# Processing Record 29 of Set 15 | neuquen
# Processing Record 30 of Set 15 | dujuma
# City not found. Skipping...
# Processing Record 31 of Set 15 | tambacounda
# Processing Record 32 of Set 15 | castanos
# Processing Record 33 of Set 15 | benito juarez
# Processing Record 34 of Set 15 | cap malheureux
# Processing Record 35 of Set 15 | hambantota
# Processing Record 36 of Set 15 | vrangel
# Processing Record 37 of Set 15 | porbandar
# Processing Record 38 of Set 15 | coihaique
# Processing Record 39 of Set 15 | zhanjiang
# Processing Record 40 of Set 15 | la union
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Castro -24.7911  -50.0119     64.22        96         100
# 1           Chuy -33.6971  -53.4616     71.15        92           0
# 2         Payson  40.0444 -111.7321     36.00        75          90
# 3         Albany  42.6001  -73.9662     19.00        46          43
# 4           Hilo  19.7297 -155.0900     78.80        65          40
# 5   Saint-Joseph -21.3667   55.6167     78.80        73           0
# 6      Geraldton -28.7667  114.6000     70.70        65          74
# 7          Visby  57.6409   18.2960     35.60        93          90
# 8   Puerto Ayora  -0.7393  -90.3518     84.20        65          20
# 9  Mar Del Plata -38.0023  -57.5575     75.99        88           0
#
#    Wind Speed Country       Description                 Date
# 0        4.72      BR        light rain  2021-01-24 23:38:52
# 1        7.27      UY         clear sky  2021-01-24 23:35:53
# 2        9.22      US   overcast clouds  2021-01-24 23:36:04
# 3        4.00      US  scattered clouds  2021-01-24 23:35:57
# 4        6.91      US     moderate rain  2021-01-24 23:35:44
# 5        3.44      RE     moderate rain  2021-01-24 23:38:53
# 6       13.89      AU     broken clouds  2021-01-24 23:38:53
# 7       14.97      SE        light snow  2021-01-24 23:38:53
# 8       13.80      EC        light rain  2021-01-24 23:38:53
# 9       16.11      AR         clear sky  2021-01-24 23:38:48

# %%
# Rearrange column orders in dataframe.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Description", "Date"]
city_data_df = city_data_df[new_column_order]
city_data_df.head()
# Out:
#      City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Castro      BR -24.7911  -50.0119     64.22        96         100
# 1    Chuy      UY -33.6971  -53.4616     71.15        92           0
# 2  Payson      US  40.0444 -111.7321     36.00        75          90
# 3  Albany      US  42.6001  -73.9662     19.00        46          43
# 4    Hilo      US  19.7297 -155.0900     78.80        65          40
#
#    Wind Speed       Description                 Date
# 0        4.72        light rain  2021-01-24 23:38:52
# 1        7.27         clear sky  2021-01-24 23:35:53
# 2        9.22   overcast clouds  2021-01-24 23:36:04
# 3        4.00  scattered clouds  2021-01-24 23:35:57
# 4        6.91     moderate rain  2021-01-24 23:35:44

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
